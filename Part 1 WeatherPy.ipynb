# %% [markdown]
# ## WeatherPy
# ----
#
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install citipy

# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %%
#print(cities)

# %%
#replace space with + sign for url prep
cities = [city.replace(' ', '+') for city in cities]
#cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build query URL and request your results in Celsius
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#actual
#query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

#full form of actual
#query_url = f"https://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}q={city}&units={units}"

#test url
query_url_test = f"{url}appid={weather_api_key}&q={cities[23]}&units={units}"
print(query_url_test)
# Get weather data (test)
city_response = requests.get(query_url_test)
city_json = city_response.json()
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=6f153332627c4540983d5e0900d176bd&q=new+norfolk&units=imperial

# %%
#test json dumps
print(json.dumps(city_json, indent=4))
# Out:
# {
#     "coord": {
#         "lon": 147.0587,
#         "lat": -42.7826
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 49.66,
#         "feels_like": 42.82,
#         "temp_min": 46,
#         "temp_max": 53.6,
#         "pressure": 1004,
#         "humidity": 54
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 21.85,
#         "deg": 230,
#         "gust": 34.52
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1618461415,
#     "sys": {
#         "type": 1,
#         "id": 9545,
#         "country": "AU",
#         "sunrise": 1618433003,
#         "sunset": 1618472394
#     },
#     "timezone": 36000,
#     "id": 2155415,
#     "name": "New Norfolk",
#     "cod": 200
# }

# %%
#testing where needed data is in the json file
print(city_json["coord"])
print(city_json["coord"]["lon"])
print(city_json["coord"]["lat"])
print(city_json["main"]["temp_max"])
print(city_json["main"]["humidity"])
print(city_json["clouds"]["all"])
print(city_json["wind"]["speed"])
print(city_json["sys"]["country"])
print(city_json["dt"])
print(city_json["name"])
# Out:
# {'lon': 147.0587, 'lat': -42.7826}
# 147.0587
# -42.7826
# 53.6
# 54
# 75
# 21.85
# AU
# 1618461415
# New Norfolk

# %%
count = 1
groupcount = 1
#remaking cities list in case a city can't be found in api
city_name = []
lon = []
lat = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
linebreak = "---------------------------------------------------------------------------"

print("Beginning Data Retrieval")
print(linebreak)

for city in cities:
    
    query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
#    print(query_url)
    
    try:
        city_response = requests.get(query_url)
        city_json = city_response.json()
        city_name.append(city_json["name"])
        lon.append(city_json["coord"]["lon"])
        lat.append(city_json["coord"]["lat"])
        max_temp.append(city_json["main"]["temp_max"])
        humidity.append(city_json["main"]["humidity"])
        cloudiness.append(city_json["clouds"]["all"])
        wind_speed.append(city_json["wind"]["speed"])
        country.append(city_json["sys"]["country"])
        date.append(city_json["dt"])
        
        print(f"Processing Record {count} of Set {groupcount} | {city}")
        count += 1
        
    except:
        print("City not found. Skipping ...")
        pass
        
    if count > 50:
            groupcount += 1
            count = 1
            
print(linebreak)
print("Data Retrieval Complete")
print(linebreak)
# Out:
# Beginning Data Retrieval
# ---------------------------------------------------------------------------
# Processing Record 1 of Set 1 | sola
# Processing Record 2 of Set 1 | rikitea
# City not found. Skipping ...
# Processing Record 3 of Set 1 | arys
# Processing Record 4 of Set 1 | bathsheba
# Processing Record 5 of Set 1 | malabo
# Processing Record 6 of Set 1 | yulara
# Processing Record 7 of Set 1 | fukue
# City not found. Skipping ...
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | punta+arenas
# Processing Record 11 of Set 1 | fougeres
# Processing Record 12 of Set 1 | kedrovyy
# Processing Record 13 of Set 1 | clyde+river
# Processing Record 14 of Set 1 | niihama
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | vanimo
# Processing Record 18 of Set 1 | sovetskiy
# Processing Record 19 of Set 1 | caboolture
# Processing Record 20 of Set 1 | rawson
# Processing Record 21 of Set 1 | iranshahr
# Processing Record 22 of Set 1 | new+norfolk
# Processing Record 23 of Set 1 | victoria+point
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | garissa
# Processing Record 27 of Set 1 | tasiilaq
# City not found. Skipping ...
# Processing Record 28 of Set 1 | moron
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | lebu
# City not found. Skipping ...
# Processing Record 31 of Set 1 | te+anau
# Processing Record 32 of Set 1 | bluff
# City not found. Skipping ...
# Processing Record 33 of Set 1 | mounana
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | ribeira+grande
# Processing Record 36 of Set 1 | bac+lieu
# Processing Record 37 of Set 1 | norman+wells
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | richards+bay
# Processing Record 40 of Set 1 | broome
# Processing Record 41 of Set 1 | nelson+bay
# Processing Record 42 of Set 1 | san+martin
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | omsukchan
# Processing Record 46 of Set 1 | silver+city
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | asfi
# Processing Record 50 of Set 1 | northam
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | brazzaville
# Processing Record 4 of Set 2 | belyy
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | taranto
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | kachug
# Processing Record 10 of Set 2 | samarai
# Processing Record 11 of Set 2 | pokhara
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | maumere
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | tagusao
# Processing Record 18 of Set 2 | guerrero+negro
# Processing Record 19 of Set 2 | baracoa
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | san+carlos
# Processing Record 22 of Set 2 | lincoln
# City not found. Skipping ...
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | cabo+san+lucas
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | chapais
# Processing Record 27 of Set 2 | russell
# Processing Record 28 of Set 2 | pangnirtung
# Processing Record 29 of Set 2 | coquimbo
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 30 of Set 2 | puerto+baquerizo+moreno
# Processing Record 31 of Set 2 | ambajogai
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | hilo
# City not found. Skipping ...
# Processing Record 35 of Set 2 | itoman
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | agadir
# Processing Record 41 of Set 2 | port+blair
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | sao+filipe
# Processing Record 44 of Set 2 | crotone
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | victoria
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | port+alfred
# Processing Record 49 of Set 2 | guaymas
# Processing Record 50 of Set 2 | grindavik
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | meulaboh
# City not found. Skipping ...
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | codrington
# City not found. Skipping ...
# Processing Record 5 of Set 3 | banda+aceh
# Processing Record 6 of Set 3 | kamenka
# City not found. Skipping ...
# Processing Record 7 of Set 3 | port+keats
# Processing Record 8 of Set 3 | takoradi
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | labuhan
# Processing Record 11 of Set 3 | port+hardy
# Processing Record 12 of Set 3 | haines+junction
# Processing Record 13 of Set 3 | vostok
# City not found. Skipping ...
# Processing Record 14 of Set 3 | arraial+do+cabo
# Processing Record 15 of Set 3 | frontera
# Processing Record 16 of Set 3 | zhenlai
# Processing Record 17 of Set 3 | alexandria
# Processing Record 18 of Set 3 | sharan
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | satuk
# Processing Record 21 of Set 3 | moundou
# City not found. Skipping ...
# Processing Record 22 of Set 3 | dingle
# Processing Record 23 of Set 3 | mnogovershinnyy
# Processing Record 24 of Set 3 | mawlaik
# Processing Record 25 of Set 3 | tiksi
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | busselton
# Processing Record 28 of Set 3 | monteagudo
# City not found. Skipping ...
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | xiamen
# Processing Record 31 of Set 3 | curico
# Processing Record 32 of Set 3 | grand+gaube
# Processing Record 33 of Set 3 | touros
# Processing Record 34 of Set 3 | kokopo
# Processing Record 35 of Set 3 | okato
# Processing Record 36 of Set 3 | kurchum
# Processing Record 37 of Set 3 | piranhas
# Processing Record 38 of Set 3 | kirensk
# Processing Record 39 of Set 3 | ulaanbaatar
# Processing Record 40 of Set 3 | puerto+ayora
# Processing Record 41 of Set 3 | kanonji
# Processing Record 42 of Set 3 | mar+del+plata
# Processing Record 43 of Set 3 | deputatskiy
# Processing Record 44 of Set 3 | kisangani
# Processing Record 45 of Set 3 | husavik
# Processing Record 46 of Set 3 | ripoll
# Processing Record 47 of Set 3 | pehowa
# Processing Record 48 of Set 3 | mahibadhoo
# Processing Record 49 of Set 3 | gladstone
# Processing Record 50 of Set 3 | cape+town
# Processing Record 1 of Set 4 | dennery
# Processing Record 2 of Set 4 | kalmunai
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | margate
# Processing Record 5 of Set 4 | sioux+lookout
# Processing Record 6 of Set 4 | guarapari
# Processing Record 7 of Set 4 | manavalakurichi
# Processing Record 8 of Set 4 | los+llanos+de+aridane
# City not found. Skipping ...
# Processing Record 9 of Set 4 | saumur
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | saint+george
# Processing Record 12 of Set 4 | antofagasta
# Processing Record 13 of Set 4 | mecca
# Processing Record 14 of Set 4 | waipawa
# Processing Record 15 of Set 4 | havre-saint-pierre
# Processing Record 16 of Set 4 | campana
# Processing Record 17 of Set 4 | hirara
# Processing Record 18 of Set 4 | tazmalt
# Processing Record 19 of Set 4 | nagato
# Processing Record 20 of Set 4 | lahat
# City not found. Skipping ...
# Processing Record 21 of Set 4 | nazca
# City not found. Skipping ...
# Processing Record 22 of Set 4 | zhanaozen
# Processing Record 23 of Set 4 | holoby
# Processing Record 24 of Set 4 | broken+hill
# Processing Record 25 of Set 4 | caucaia
# Processing Record 26 of Set 4 | alofi
# Processing Record 27 of Set 4 | hambantota
# Processing Record 28 of Set 4 | lavrentiya
# Processing Record 29 of Set 4 | cayenne
# Processing Record 30 of Set 4 | egvekinot
# Processing Record 31 of Set 4 | edd
# Processing Record 32 of Set 4 | verkhnyaya+maksakovka
# Processing Record 33 of Set 4 | east+london
# Processing Record 34 of Set 4 | isangel
# Processing Record 35 of Set 4 | newtownards
# Processing Record 36 of Set 4 | nouadhibou
# Processing Record 37 of Set 4 | yeppoon
# Processing Record 38 of Set 4 | dicabisagan
# Processing Record 39 of Set 4 | cockburn+town
# Processing Record 40 of Set 4 | mayenne
# Processing Record 41 of Set 4 | tual
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | trebinje
# Processing Record 44 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 4 | aykhal
# Processing Record 46 of Set 4 | wana
# Processing Record 47 of Set 4 | peleduy
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | avarua
# Processing Record 50 of Set 4 | peniche
# Processing Record 1 of Set 5 | roma
# Processing Record 2 of Set 5 | valdivia
# Processing Record 3 of Set 5 | mamakan
# Processing Record 4 of Set 5 | santiago+del+estero
# Processing Record 5 of Set 5 | hue
# Processing Record 6 of Set 5 | mikuni
# Processing Record 7 of Set 5 | kavieng
# Processing Record 8 of Set 5 | monki
# Processing Record 9 of Set 5 | nago
# City not found. Skipping ...
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | san+cristobal
# Processing Record 12 of Set 5 | doha
# Processing Record 13 of Set 5 | kijang
# Processing Record 14 of Set 5 | great+falls
# Processing Record 15 of Set 5 | idrinskoye
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | iqaluit
# Processing Record 18 of Set 5 | matina
# Processing Record 19 of Set 5 | berlevag
# Processing Record 20 of Set 5 | aswan
# Processing Record 21 of Set 5 | yelizovo
# Processing Record 22 of Set 5 | ivrea
# Processing Record 23 of Set 5 | maneadero
# Processing Record 24 of Set 5 | alihe
# Processing Record 25 of Set 5 | henties+bay
# Processing Record 26 of Set 5 | nanortalik
# Processing Record 27 of Set 5 | sambava
# Processing Record 28 of Set 5 | paracuru
# Processing Record 29 of Set 5 | pacific+grove
# Processing Record 30 of Set 5 | korla
# Processing Record 31 of Set 5 | mulege
# Processing Record 32 of Set 5 | kidal
# City not found. Skipping ...
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | bolu
# Processing Record 35 of Set 5 | tambacounda
# Processing Record 36 of Set 5 | riyadh
# Processing Record 37 of Set 5 | tommot
# Processing Record 38 of Set 5 | pisco
# Processing Record 39 of Set 5 | ankang
# Processing Record 40 of Set 5 | bilibino
# Processing Record 41 of Set 5 | pitimbu
# Processing Record 42 of Set 5 | nhulunbuy
# Processing Record 43 of Set 5 | san+patricio
# City not found. Skipping ...
# Processing Record 44 of Set 5 | port+lincoln
# Processing Record 45 of Set 5 | niamey
# Processing Record 46 of Set 5 | guasdualito
# Processing Record 47 of Set 5 | kahului
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | castanheira+de+pera
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 50 of Set 5 | la+cruz
# Processing Record 1 of Set 6 | faya
# Processing Record 2 of Set 6 | luocheng
# Processing Record 3 of Set 6 | bambous+virieux
# Processing Record 4 of Set 6 | whitehorse
# Processing Record 5 of Set 6 | kjollefjord
# Processing Record 6 of Set 6 | west+point
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | mehamn
# Processing Record 9 of Set 6 | shangrao
# Processing Record 10 of Set 6 | ancud
# Processing Record 11 of Set 6 | sorland
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | chegdomyn
# Processing Record 14 of Set 6 | sakaraha
# Processing Record 15 of Set 6 | ust-barguzin
# Processing Record 16 of Set 6 | gayeri
# Processing Record 17 of Set 6 | muzhi
# Processing Record 18 of Set 6 | constitucion
# Processing Record 19 of Set 6 | muros
# Processing Record 20 of Set 6 | taunggyi
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | bowral
# Processing Record 23 of Set 6 | qaqortoq
# Processing Record 24 of Set 6 | cabedelo
# Processing Record 25 of Set 6 | port+elizabeth
# Processing Record 26 of Set 6 | kudat
# Processing Record 27 of Set 6 | altay
# Processing Record 28 of Set 6 | talnakh
# Processing Record 29 of Set 6 | padang
# Processing Record 30 of Set 6 | lere
# Processing Record 31 of Set 6 | okhotsk
# Processing Record 32 of Set 6 | hasaki
# Processing Record 33 of Set 6 | sitka
# Processing Record 34 of Set 6 | ketchikan
# Processing Record 35 of Set 6 | fomboni
# Processing Record 36 of Set 6 | jieshi
# Processing Record 37 of Set 6 | luanda
# Processing Record 38 of Set 6 | paamiut
# Processing Record 39 of Set 6 | jizan
# Processing Record 40 of Set 6 | surt
# City not found. Skipping ...
# Processing Record 41 of Set 6 | matara
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | ramsar
# City not found. Skipping ...
# Processing Record 44 of Set 6 | kuruman
# Processing Record 45 of Set 6 | payo
# Processing Record 46 of Set 6 | mackay
# Processing Record 47 of Set 6 | provideniya
# Processing Record 48 of Set 6 | taoudenni
# Processing Record 49 of Set 6 | santa+rosa
# Processing Record 50 of Set 6 | grand-santi
# Processing Record 1 of Set 7 | lang+son
# Processing Record 2 of Set 7 | yantal
# City not found. Skipping ...
# Processing Record 3 of Set 7 | kingaroy
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | pineville
# Processing Record 6 of Set 7 | jurado
# Processing Record 7 of Set 7 | mul
# Processing Record 8 of Set 7 | keetmanshoop
# Processing Record 9 of Set 7 | kuryk
# Processing Record 10 of Set 7 | abu+kamal
# Processing Record 11 of Set 7 | bay+roberts
# Processing Record 12 of Set 7 | cap-aux-meules
# Processing Record 13 of Set 7 | susanville
# Processing Record 14 of Set 7 | inzer
# Processing Record 15 of Set 7 | talcahuano
# Processing Record 16 of Set 7 | waiouru
# Processing Record 17 of Set 7 | pacifica
# Processing Record 18 of Set 7 | college
# Processing Record 19 of Set 7 | chicama
# Processing Record 20 of Set 7 | zaysan
# Processing Record 21 of Set 7 | del+rio
# Processing Record 22 of Set 7 | yumen
# Processing Record 23 of Set 7 | aranos
# Processing Record 24 of Set 7 | matadi
# Processing Record 25 of Set 7 | jinka
# Processing Record 26 of Set 7 | sibiti
# Processing Record 27 of Set 7 | safaga
# Processing Record 28 of Set 7 | djibo
# City not found. Skipping ...
# Processing Record 29 of Set 7 | malanje
# Processing Record 30 of Set 7 | srednekolymsk
# Processing Record 31 of Set 7 | pemangkat
# Processing Record 32 of Set 7 | esperance
# Processing Record 33 of Set 7 | auki
# Processing Record 34 of Set 7 | tangwani
# Processing Record 35 of Set 7 | bitam
# Processing Record 36 of Set 7 | tuatapere
# Processing Record 37 of Set 7 | chivilcoy
# Processing Record 38 of Set 7 | billings
# Processing Record 39 of Set 7 | les+cayes
# Processing Record 40 of Set 7 | kayiry
# Processing Record 41 of Set 7 | mitsamiouli
# Processing Record 42 of Set 7 | kaeo
# Processing Record 43 of Set 7 | tremedal
# Processing Record 44 of Set 7 | caravelas
# Processing Record 45 of Set 7 | klaksvik
# Processing Record 46 of Set 7 | jasper
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | vilhena
# Processing Record 49 of Set 7 | torbay
# Processing Record 50 of Set 7 | rio+grande
# Processing Record 1 of Set 8 | tigil
# Processing Record 2 of Set 8 | wukari
# Processing Record 3 of Set 8 | vila+velha
# Processing Record 4 of Set 8 | nampula
# Processing Record 5 of Set 8 | basco
# Processing Record 6 of Set 8 | stornoway
# Processing Record 7 of Set 8 | trairi
# City not found. Skipping ...
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | bambanglipuro
# Processing Record 10 of Set 8 | kashi
# Processing Record 11 of Set 8 | areosa
# Processing Record 12 of Set 8 | the+valley
# Processing Record 13 of Set 8 | benjamin+hill
# Processing Record 14 of Set 8 | cherskiy
# Processing Record 15 of Set 8 | saint-augustin
# Processing Record 16 of Set 8 | lumeje
# Processing Record 17 of Set 8 | sao+francisco+do+sul
# Processing Record 18 of Set 8 | ambilobe
# Processing Record 19 of Set 8 | dhidhdhoo
# Processing Record 20 of Set 8 | donskoy
# Processing Record 21 of Set 8 | moose+factory
# Processing Record 22 of Set 8 | houma
# Processing Record 23 of Set 8 | palmer
# Processing Record 24 of Set 8 | saint-joseph
# City not found. Skipping ...
# Processing Record 25 of Set 8 | antalaha
# Processing Record 26 of Set 8 | avera
# Processing Record 27 of Set 8 | ormond+beach
# Processing Record 28 of Set 8 | saint-louis
# Processing Record 29 of Set 8 | inhambane
# Processing Record 30 of Set 8 | saintes
# Processing Record 31 of Set 8 | shiyan
# Processing Record 32 of Set 8 | tessalit
# Processing Record 33 of Set 8 | aripuana
# Processing Record 34 of Set 8 | tilichiki
# Processing Record 35 of Set 8 | lasa
# Processing Record 36 of Set 8 | priiskovyy
# Processing Record 37 of Set 8 | roebourne
# Processing Record 38 of Set 8 | brigantine
# Processing Record 39 of Set 8 | ushtobe
# Processing Record 40 of Set 8 | vallenar
# Processing Record 41 of Set 8 | bosaso
# Processing Record 42 of Set 8 | byron+bay
# Processing Record 43 of Set 8 | farah
# Processing Record 44 of Set 8 | puerto+escondido
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | gasa
# Processing Record 47 of Set 8 | north+bend
# Processing Record 48 of Set 8 | sinnamary
# Processing Record 49 of Set 8 | imbituba
# Processing Record 50 of Set 8 | port+hedland
# Processing Record 1 of Set 9 | aktau
# Processing Record 2 of Set 9 | georgetown
# Processing Record 3 of Set 9 | lamentin
# Processing Record 4 of Set 9 | axim
# Processing Record 5 of Set 9 | huarmey
# Processing Record 6 of Set 9 | ust-nera
# Processing Record 7 of Set 9 | manta
# Processing Record 8 of Set 9 | erdenet
# Processing Record 9 of Set 9 | kawambwa
# City not found. Skipping ...
# Processing Record 10 of Set 9 | dunedin
# Processing Record 11 of Set 9 | katsuura
# Processing Record 12 of Set 9 | san+quintin
# Processing Record 13 of Set 9 | ukmerge
# Processing Record 14 of Set 9 | littlehampton
# Processing Record 15 of Set 9 | svetlogorsk
# Processing Record 16 of Set 9 | nisia+floresta
# Processing Record 17 of Set 9 | bahia+blanca
# Processing Record 18 of Set 9 | saldanha
# Processing Record 19 of Set 9 | ambulu
# Processing Record 20 of Set 9 | kaka
# Processing Record 21 of Set 9 | emerald
# Processing Record 22 of Set 9 | valley
# Processing Record 23 of Set 9 | cordoba
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | evanston
# Processing Record 26 of Set 9 | oneonta
# Processing Record 27 of Set 9 | nantucket
# Processing Record 28 of Set 9 | matagami
# Processing Record 29 of Set 9 | acapulco
# Processing Record 30 of Set 9 | abu+dhabi
# Processing Record 31 of Set 9 | vicosa+do+ceara
# Processing Record 32 of Set 9 | kirakira
# Processing Record 33 of Set 9 | bowen
# Processing Record 34 of Set 9 | oktyabrskiy
# Processing Record 35 of Set 9 | smithers
# Processing Record 36 of Set 9 | sines
# Processing Record 37 of Set 9 | quatre+cocos
# Processing Record 38 of Set 9 | mola+di+bari
# Processing Record 39 of Set 9 | marzuq
# Processing Record 40 of Set 9 | beaupre
# Processing Record 41 of Set 9 | komsomolskiy
# Processing Record 42 of Set 9 | tevaitoa
# Processing Record 43 of Set 9 | nizwa
# Processing Record 44 of Set 9 | wajima
# Processing Record 45 of Set 9 | biak
# Processing Record 46 of Set 9 | flagstaff
# Processing Record 47 of Set 9 | airai
# Processing Record 48 of Set 9 | vestmannaeyjar
# Processing Record 49 of Set 9 | atbasar
# Processing Record 50 of Set 9 | kemijarvi
# Processing Record 1 of Set 10 | coihueco
# City not found. Skipping ...
# Processing Record 2 of Set 10 | high+level
# Processing Record 3 of Set 10 | trelew
# Processing Record 4 of Set 10 | tikrit
# Processing Record 5 of Set 10 | tangshan
# Processing Record 6 of Set 10 | srandakan
# City not found. Skipping ...
# Processing Record 7 of Set 10 | marienburg
# Processing Record 8 of Set 10 | partenit
# Processing Record 9 of Set 10 | helong
# Processing Record 10 of Set 10 | moranbah
# City not found. Skipping ...
# Processing Record 11 of Set 10 | andenes
# Processing Record 12 of Set 10 | bojonegoro
# Processing Record 13 of Set 10 | dzilam+gonzalez
# Processing Record 14 of Set 10 | shepsi
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 15 of Set 10 | lichinga
# Processing Record 16 of Set 10 | dzerzhinsk
# Processing Record 17 of Set 10 | ust-omchug
# Processing Record 18 of Set 10 | abu+samrah
# Processing Record 19 of Set 10 | saint-georges
# Processing Record 20 of Set 10 | portland
# Processing Record 21 of Set 10 | tabou
# Processing Record 22 of Set 10 | goianesia
# Processing Record 23 of Set 10 | ayan
# Processing Record 24 of Set 10 | golyshmanovo
# Processing Record 25 of Set 10 | la+tuque
# Processing Record 26 of Set 10 | ola
# Processing Record 27 of Set 10 | tayshet
# Processing Record 28 of Set 10 | carutapera
# City not found. Skipping ...
# Processing Record 29 of Set 10 | indianola
# Processing Record 30 of Set 10 | martapura
# Processing Record 31 of Set 10 | kenai
# Processing Record 32 of Set 10 | iquique
# Processing Record 33 of Set 10 | la+ronge
# Processing Record 34 of Set 10 | saint+anthony
# Processing Record 35 of Set 10 | killybegs
# Processing Record 36 of Set 10 | sorong
# Processing Record 37 of Set 10 | barrhead
# Processing Record 38 of Set 10 | dukat
# Processing Record 39 of Set 10 | labuan
# City not found. Skipping ...
# Processing Record 40 of Set 10 | sao+mateus
# Processing Record 41 of Set 10 | boende
# Processing Record 42 of Set 10 | rio+gallegos
# Processing Record 43 of Set 10 | puerto+colombia
# Processing Record 44 of Set 10 | waw
# Processing Record 45 of Set 10 | jatiroto
# Processing Record 46 of Set 10 | moctezuma
# Processing Record 47 of Set 10 | oranjemund
# Processing Record 48 of Set 10 | chifeng
# Processing Record 49 of Set 10 | ambovombe
# Processing Record 50 of Set 10 | flinders
# Processing Record 1 of Set 11 | ahipara
# Processing Record 2 of Set 11 | warangal
# Processing Record 3 of Set 11 | sabang
# Processing Record 4 of Set 11 | chimore
# Processing Record 5 of Set 11 | kupang
# Processing Record 6 of Set 11 | hurricane
# Processing Record 7 of Set 11 | ambon
# Processing Record 8 of Set 11 | japura
# Processing Record 9 of Set 11 | khowst
# Processing Record 10 of Set 11 | bandarbeyla
# Processing Record 11 of Set 11 | presidencia+roque+saenz+pena
# Processing Record 12 of Set 11 | ayorou
# Processing Record 13 of Set 11 | cap+malheureux
# Processing Record 14 of Set 11 | teguise
# Processing Record 15 of Set 11 | eureka
# Processing Record 16 of Set 11 | manokwari
# Processing Record 17 of Set 11 | gornopravdinsk
# City not found. Skipping ...
# Processing Record 18 of Set 11 | ereymentau
# Processing Record 19 of Set 11 | opuwo
# Processing Record 20 of Set 11 | salvador
# Processing Record 21 of Set 11 | khanpur
# City not found. Skipping ...
# Processing Record 22 of Set 11 | breasta
# Processing Record 23 of Set 11 | souillac
# City not found. Skipping ...
# Processing Record 24 of Set 11 | turukhansk
# Processing Record 25 of Set 11 | zhanakorgan
# Processing Record 26 of Set 11 | adre
# Processing Record 27 of Set 11 | walvis+bay
# Processing Record 28 of Set 11 | mogadishu
# Processing Record 29 of Set 11 | havoysund
# Processing Record 30 of Set 11 | lalibela
# Processing Record 31 of Set 11 | port+macquarie
# Processing Record 32 of Set 11 | baraboo
# City not found. Skipping ...
# Processing Record 33 of Set 11 | fayaoue
# Processing Record 34 of Set 11 | mbandaka
# Processing Record 35 of Set 11 | semibratovo
# Processing Record 36 of Set 11 | ponta+do+sol
# Processing Record 37 of Set 11 | along
# Processing Record 38 of Set 11 | kosonsoy
# Processing Record 39 of Set 11 | uporovo
# Processing Record 40 of Set 11 | tshikapa
# Processing Record 41 of Set 11 | kloulklubed
# City not found. Skipping ...
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | lokosovo
# Processing Record 44 of Set 11 | paragominas
# Processing Record 45 of Set 11 | hastings
# Processing Record 46 of Set 11 | gerash
# Processing Record 47 of Set 11 | pochutla
# Processing Record 48 of Set 11 | poum
# Processing Record 49 of Set 11 | mareeba
# Processing Record 50 of Set 11 | barra+do+corda
# Processing Record 1 of Set 12 | fairbanks
# Processing Record 2 of Set 12 | areka
# Processing Record 3 of Set 12 | yaan
# Processing Record 4 of Set 12 | horizontina
# Processing Record 5 of Set 12 | luwuk
# Processing Record 6 of Set 12 | salinopolis
# Processing Record 7 of Set 12 | gravdal
# Processing Record 8 of Set 12 | beringovskiy
# Processing Record 9 of Set 12 | kudahuvadhoo
# Processing Record 10 of Set 12 | nalut
# Processing Record 11 of Set 12 | severomuysk
# Processing Record 12 of Set 12 | portoferraio
# Processing Record 13 of Set 12 | leh
# Processing Record 14 of Set 12 | ndjole
# Processing Record 15 of Set 12 | ulaangom
# Processing Record 16 of Set 12 | trinidad
# Processing Record 17 of Set 12 | laguna
# Processing Record 18 of Set 12 | bilma
# Processing Record 19 of Set 12 | brumado
# Processing Record 20 of Set 12 | varkaus
# Processing Record 21 of Set 12 | carire
# Processing Record 22 of Set 12 | issoire
# Processing Record 23 of Set 12 | batsfjord
# Processing Record 24 of Set 12 | sao+felix+do+xingu
# Processing Record 25 of Set 12 | sweetwater
# Processing Record 26 of Set 12 | uch
# Processing Record 27 of Set 12 | ludvika
# ---------------------------------------------------------------------------
# Data Retrieval Complete
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
dict = {"City": city_name, "Latitude": lat, "Longitute": lon, "Max Temp (F)": max_temp, "Humidity": humidity, 
       "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Country": country, "Date": date}
cities_df = pd.DataFrame(dict)
cities_df.head()
# Out:
#         City  Latitude  Longitute  Max Temp (F)  Humidity  Cloudiness  \
# 0       Sola  -13.8833   167.5500         89.60        66          40
# 1    Rikitea  -23.1203  -134.9692         78.57        72          13
# 2       Arys   42.4252    68.7950         60.80        55          40
# 3  Bathsheba   13.2167   -59.5167         78.80        69          20
# 4     Malabo    3.7500     8.7833         80.60        89          20
#
#    Wind Speed Country        Date
# 0        2.30      VU  1618461446
# 1        8.68      PF  1618461447
# 2        6.71      KZ  1618461447
# 3        8.05      BB  1618461372
# 4        3.44      GQ  1618461447

# %%
cities_df.to_csv("Output/cities.csv", sep=",", encoding='utf-8',index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
